# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


# from scores.score_logger import ScoreLogger
# Out:
# C:\Dev\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

# %%
ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995

# %%
env = gym.make(ENV_NAME)

observation_space = env.observation_space.shape[0]
action_space = env.action_space.n
dqn_solver = DQNSolver(observation_space, action_space)
run = 0
while True:
    run += 1
    state = env.reset()
    state = np.reshape(state, [1, observation_space])
    step = 0
    while True:
        step += 1
        #env.render()
        action = dqn_solver.act(state)
        state_next, reward, terminal, info = env.step(action)
        reward = reward if not terminal else -reward
        state_next = np.reshape(state_next, [1, observation_space])
        dqn_solver.remember(state, action, reward, state_next, terminal)
        state = state_next
        if terminal:
            print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
            break
        dqn_solver.experience_replay()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Run: 2, exploration: 0.9369146928798039, score: 14
# Run: 3, exploration: 0.8866535105013078, score: 12
# Run: 4, exploration: 0.8183201210226743, score: 17
# Run: 5, exploration: 0.7590483508202912, score: 16
# Run: 6, exploration: 0.7040696960536299, score: 16
# Run: 7, exploration: 0.6596532430440636, score: 14
# Run: 8, exploration: 0.6337242817644086, score: 9
# Run: 9, exploration: 0.5790496471185967, score: 19
# Run: 10, exploration: 0.5398075216808175, score: 15
# Run: 11, exploration: 0.5082950737585841, score: 13
# Run: 12, exploration: 0.47862223409330756, score: 13
# Run: 13, exploration: 0.4529463432347434, score: 12
# Run: 14, exploration: 0.4159480862733536, score: 18
# Run: 15, exploration: 0.3897078735047413, score: 14
# Run: 16, exploration: 0.3743896431025813, score: 9
# Run: 17, exploration: 0.35253382661792404, score: 13
# Run: 18, exploration: 0.3352984938281715, score: 11
# Run: 19, exploration: 0.322118930542046, score: 9
# Run: 20, exploration: 0.3063705780533402, score: 11
# Run: 21, exploration: 0.2943280830920294, score: 9
# Run: 22, exploration: 0.27853872940185365, score: 12
# Run: 23, exploration: 0.2662522686041882, score: 10
# Run: 24, exploration: 0.25450776877280124, score: 10
# Run: 25, exploration: 0.24328132378095624, score: 10
# Run: 26, exploration: 0.23371867538818816, score: 9
# Run: 27, exploration: 0.22453190559909803, score: 9
# Run: 28, exploration: 0.21570623976979014, score: 9
# Run: 29, exploration: 0.2041345879004775, score: 12
# Run: 30, exploration: 0.19611067854912728, score: 9
# Run: 31, exploration: 0.18840216465300522, score: 9
# Run: 32, exploration: 0.18099664897669618, score: 9
# Run: 33, exploration: 0.17388222158237718, score: 9
# Run: 34, exploration: 0.16538114245489302, score: 11
# Run: 35, exploration: 0.15417328217978102, score: 15
# Run: 36, exploration: 0.14663577052834775, score: 11
# Run: 37, exploration: 0.14087196468590776, score: 9
# Run: 38, exploration: 0.1353347165085562, score: 9
# Run: 39, exploration: 0.13001512070402377, score: 9
# Run: 40, exploration: 0.1255322834371622, score: 8
# Run: 41, exploration: 0.11999500148501063, score: 10
# Run: 42, exploration: 0.11470197137452155, score: 10
# Run: 43, exploration: 0.10964241905397228, score: 10
# Run: 44, exploration: 0.10480604571960442, score: 10
# Run: 45, exploration: 0.10018300685223579, score: 10
# Run: 46, exploration: 0.09576389217857617, score: 10
# Run: 47, exploration: 0.09153970651645797, score: 10
# Run: 48, exploration: 0.08662902049662846, score: 12
# Run: 49, exploration: 0.08364210790237678, score: 8
# Run: 50, exploration: 0.07915509187866444, score: 12
# Run: 51, exploration: 0.07566352740075044, score: 10
# Run: 52, exploration: 0.07232597730414898, score: 10
# Run: 53, exploration: 0.06878996970981359, score: 11
# Run: 54, exploration: 0.06542683706543727, score: 11
# Run: 55, exploration: 0.06254083169574957, score: 10
# Run: 56, exploration: 0.0543512971290831, score: 29
# Run: 57, exploration: 0.05195383849590569, score: 10
# Run: 58, exploration: 0.04425437624418858, score: 33
# Run: 59, exploration: 0.04230229704853423, score: 10
# Run: 60, exploration: 0.040032972548509065, score: 12
# Run: 61, exploration: 0.0378853869148274, score: 12
# Run: 62, exploration: 0.033423255248208356, score: 26
# Run: 63, exploration: 0.028186002814352063, score: 35
# Run: 64, exploration: 0.022949847368015076, score: 42
# Run: 65, exploration: 0.018686420266267767, score: 42
# Run: 66, exploration: 0.015445542985048652, score: 39
# Run: 67, exploration: 0.012203600316175803, score: 48
# Run: 68, exploration: 0.010499784796482848, score: 31
# Run: 69, exploration: 0.01, score: 29
# Run: 70, exploration: 0.01, score: 21
# Run: 71, exploration: 0.01, score: 18
# Run: 72, exploration: 0.01, score: 16
# Run: 73, exploration: 0.01, score: 22
# Run: 74, exploration: 0.01, score: 24
# Run: 75, exploration: 0.01, score: 19
# Run: 76, exploration: 0.01, score: 46
# Run: 77, exploration: 0.01, score: 34
# Run: 78, exploration: 0.01, score: 22
# Run: 79, exploration: 0.01, score: 19
# Run: 80, exploration: 0.01, score: 23
# Run: 81, exploration: 0.01, score: 22
# Run: 82, exploration: 0.01, score: 69
# Run: 83, exploration: 0.01, score: 13
# Run: 84, exploration: 0.01, score: 49
# Run: 85, exploration: 0.01, score: 24
# Run: 86, exploration: 0.01, score: 16
# Run: 87, exploration: 0.01, score: 27
# Run: 88, exploration: 0.01, score: 15
# Run: 89, exploration: 0.01, score: 19
# Run: 90, exploration: 0.01, score: 18
# Run: 91, exploration: 0.01, score: 23
# Run: 92, exploration: 0.01, score: 13
# Run: 93, exploration: 0.01, score: 17
# Run: 94, exploration: 0.01, score: 29
# Run: 95, exploration: 0.01, score: 31
# Run: 96, exploration: 0.01, score: 28
# Run: 97, exploration: 0.01, score: 25
# Run: 98, exploration: 0.01, score: 14
# Run: 99, exploration: 0.01, score: 44
# Run: 100, exploration: 0.01, score: 15
# Run: 101, exploration: 0.01, score: 19
# Run: 102, exploration: 0.01, score: 65
# Run: 103, exploration: 0.01, score: 72
# Run: 104, exploration: 0.01, score: 23
# Run: 105, exploration: 0.01, score: 25
# Run: 106, exploration: 0.01, score: 34
# Run: 107, exploration: 0.01, score: 33
# Run: 108, exploration: 0.01, score: 42
# Run: 109, exploration: 0.01, score: 90
# Run: 110, exploration: 0.01, score: 54
# Run: 111, exploration: 0.01, score: 56
# Run: 112, exploration: 0.01, score: 52
# Run: 113, exploration: 0.01, score: 74
# Run: 114, exploration: 0.01, score: 110
# Run: 115, exploration: 0.01, score: 49
# Run: 116, exploration: 0.01, score: 80
# Run: 117, exploration: 0.01, score: 58
# Run: 118, exploration: 0.01, score: 398
# Run: 119, exploration: 0.01, score: 299
# Run: 120, exploration: 0.01, score: 149
# Run: 121, exploration: 0.01, score: 201
# Run: 122, exploration: 0.01, score: 164
# Run: 123, exploration: 0.01, score: 148
# Run: 124, exploration: 0.01, score: 154
# Run: 125, exploration: 0.01, score: 136
# Run: 126, exploration: 0.01, score: 112
# Run: 127, exploration: 0.01, score: 133
# Run: 128, exploration: 0.01, score: 139
# Run: 129, exploration: 0.01, score: 171
# Run: 130, exploration: 0.01, score: 257
# Run: 131, exploration: 0.01, score: 198
# Run: 132, exploration: 0.01, score: 210
# Run: 133, exploration: 0.01, score: 403
# Run: 134, exploration: 0.01, score: 209
# Run: 135, exploration: 0.01, score: 136
# Run: 136, exploration: 0.01, score: 177
# Run: 137, exploration: 0.01, score: 129
# Run: 138, exploration: 0.01, score: 127
# Run: 139, exploration: 0.01, score: 92
# Run: 140, exploration: 0.01, score: 103
# Run: 141, exploration: 0.01, score: 101
# Run: 142, exploration: 0.01, score: 144
# Run: 143, exploration: 0.01, score: 184
# Run: 144, exploration: 0.01, score: 164
# Run: 145, exploration: 0.01, score: 171
# Run: 146, exploration: 0.01, score: 163
# Run: 147, exploration: 0.01, score: 190
# Run: 148, exploration: 0.01, score: 135
# Run: 149, exploration: 0.01, score: 156
# Run: 150, exploration: 0.01, score: 162
# Run: 151, exploration: 0.01, score: 190
# Run: 152, exploration: 0.01, score: 139
# Run: 153, exploration: 0.01, score: 152
# Run: 154, exploration: 0.01, score: 155
# Run: 155, exploration: 0.01, score: 202
# Run: 156, exploration: 0.01, score: 215
# Run: 157, exploration: 0.01, score: 149
# Run: 158, exploration: 0.01, score: 127
# Run: 159, exploration: 0.01, score: 174
# Run: 160, exploration: 0.01, score: 160
# Run: 161, exploration: 0.01, score: 148
# Run: 162, exploration: 0.01, score: 188
# Run: 163, exploration: 0.01, score: 186
# Run: 164, exploration: 0.01, score: 207
# Run: 165, exploration: 0.01, score: 193
# Run: 166, exploration: 0.01, score: 150
# Run: 167, exploration: 0.01, score: 163
# Run: 168, exploration: 0.01, score: 237
# Run: 169, exploration: 0.01, score: 184
# Run: 170, exploration: 0.01, score: 182
# Run: 171, exploration: 0.01, score: 201
# Run: 172, exploration: 0.01, score: 134
# Run: 173, exploration: 0.01, score: 160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1fd6960f7bd6> in <module>()
#      22             print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
#      23             break
# ---> 24         dqn_solver.experience_replay()
#
# <ipython-input-3-9b130d0f8850> in experience_replay(self)
#      29             q_update = reward
#      30             if not terminal:
# ---> 31                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      32             q_values = self.model.predict(state)
#      33             q_values[0][action] = q_update
#
# C:\Dev\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# C:\Dev\anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# C:\Dev\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# C:\Dev\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# C:\Dev\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
